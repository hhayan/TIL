# %%
# Structured Data 정형 데이터 -> 앙상블 학습
# 대부분의 앙상블 학습은 트리 기반

import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split

wine = pd.read_csv('./wine.csv')
X = wine[['al']]
